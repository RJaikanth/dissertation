# %%
import c3d

f = open("/home/rjaikanth97/myspace/dissertation-helpers/datasets/ASPSet/trainval/joints_3d/4d9e/4d9e-0006.c3d", "rb")
reader = c3d.Reader(f)

for i, points, _ in reader.read_frames():
    print(f"Frame: {i}, Point: {points.shape}")

f.close()
# Out:
# Frame: 1, Point: (17, 5)
# Frame: 2, Point: (17, 5)
# Frame: 3, Point: (17, 5)
# Frame: 4, Point: (17, 5)
# Frame: 5, Point: (17, 5)
# Frame: 6, Point: (17, 5)
# Frame: 7, Point: (17, 5)
# Frame: 8, Point: (17, 5)
# Frame: 9, Point: (17, 5)
# Frame: 10, Point: (17, 5)
# Frame: 11, Point: (17, 5)
# Frame: 12, Point: (17, 5)
# Frame: 13, Point: (17, 5)
# Frame: 14, Point: (17, 5)
# Frame: 15, Point: (17, 5)
# Frame: 16, Point: (17, 5)
# Frame: 17, Point: (17, 5)
# Frame: 18, Point: (17, 5)
# Frame: 19, Point: (17, 5)
# Frame: 20, Point: (17, 5)
# Frame: 21, Point: (17, 5)
# Frame: 22, Point: (17, 5)
# Frame: 23, Point: (17, 5)
# Frame: 24, Point: (17, 5)
# Frame: 25, Point: (17, 5)
# Frame: 26, Point: (17, 5)
# Frame: 27, Point: (17, 5)
# Frame: 28, Point: (17, 5)
# Frame: 29, Point: (17, 5)
# Frame: 30, Point: (17, 5)
# Frame: 31, Point: (17, 5)
# Frame: 32, Point: (17, 5)
# Frame: 33, Point: (17, 5)
# Frame: 34, Point: (17, 5)
# Frame: 35, Point: (17, 5)
# Frame: 36, Point: (17, 5)
# ...
